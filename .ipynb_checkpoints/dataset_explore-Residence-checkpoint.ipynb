# %% [markdown]
# # Dataset Exploration

# %%
import math
import numpy as np
from sklearn import linear_model
import scipy.stats as stats
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = "../State_of_Iowa_Salary_Book.csv"

# %%
def money_to_float(x):
    try:
        if type(x) == float:
            return x
        return float(x.strip('$'))
    except ValueError:
        return float('nan')

def base_salary_to_float(x):
    try:
        if type(x) == float and math.isnan(x):
            return (None, float('nan'))
        elif type(x) == float:
            return (None, x)
        x = x.strip(" ")
        if x == "":
            return (None, float('nan'))
        elif x == "TERMINATED":
            return ("TERMINATED", float('nan'))
        elif x == "Terminated":
            return ("Terminated", float('nan'))
        elif x == "-0-":
            return ("-0-", float('nan'))
        elif x == "ON LEAVE":
            return ("ON LEAVE", float('nan'))
        elif x == "nan":
            return (None, float('nan'))
        elif x == float("nan"):
            return (None, float('nan'))
        else:
            s = x.replace('/', " ").split(' ')
            if len(s) < 2:
                return (None, float(s[0].strip('$').replace(',', "")))
            return (s[1], float(s[0].strip('$').replace(',', "")))
    except:
        # this is to show rows that failed the parsing
        print("<-"+x+"->", type(x))

# %%
# read csv
data = pd.read_csv(path, parse_dates=[0,8], converters={'Total Salary Paid': money_to_float, 'Base Salary': base_salary_to_float, 'Travel & Subsistence': money_to_float})
# split Base Salary tuple into two columns
base_salary_parsed = data["Base Salary"].apply(pd.Series).rename(columns={0:'Base Salary Payment Method', 1:'Base Salary Payment Amount'})
data.insert(8, 'Base Salary Payment Method', base_salary_parsed['Base Salary Payment Method'])
data.insert(9, 'Base Salary Payment Amount', base_salary_parsed['Base Salary Payment Amount'])
# delete Base Salary tuple column
data.pop("Base Salary")
# Out:
# ('<-HR->', <type 'str'>)
# ('<-YR->', <type 'str'>)
# ('<-20.12HR->', <type 'str'>)
# ('<-262.99DA->', <type 'str'>)
# 0               (HR, 31.62)
# 1         (TERMINATED, nan)
# 2              (BW, 2212.8)
# 3              (BW, 1226.4)
# 4         (TERMINATED, nan)
# 5         (TERMINATED, nan)
# 6         (TERMINATED, nan)
# 7         (TERMINATED, nan)
# 8              (BW, 2194.4)
# 9         (TERMINATED, nan)
# 10        (TERMINATED, nan)
# 11        (TERMINATED, nan)
# 12             (BW, 3375.2)
# 13        (TERMINATED, nan)
# 14        (TERMINATED, nan)
# 15             (BW, 3349.6)
# 16           (YR, 144200.0)
# 17             (BW, 1237.6)
# 18             (BW, 2908.8)
# 19             (BW, 3193.6)
# 20        (TERMINATED, nan)
# 21             (BW, 1598.4)
# 22        (TERMINATED, nan)
# 23        (TERMINATED, nan)
# 24        (TERMINATED, nan)
# 25        (TERMINATED, nan)
# 26             (BW, 1180.8)
# 27             (BW, 3087.2)
# 28             (BW, 1437.6)
# 29             (BW, 4792.0)
#                 ...
# 665295          (HR, 23.91)
# 665296        (HR, 25629.0)
# 665297          (HR, 22.88)
# 665298    (TERMINATED, nan)
# 665299          (HR, 16.83)
# 665300        (YR, 70158.0)
# 665301          (HR, 17.56)
# 665302        (YR, 53638.0)
# 665303    (TERMINATED, nan)
# 665304          (HR, 16.83)
# 665305          (HR, 16.83)
# 665306        (YR, 81255.0)
# 665307        (YR, 87138.0)
# 665308        (YR, 72101.0)
# 665309          (HR, 16.83)
# 665310          (HR, 16.83)
# 665311          (HR, 16.83)
# 665312        (YR, 59663.0)
# 665313        (YR, 58609.0)
# 665314          (HR, 20.45)
# 665315          (HR, 21.44)
# 665316    (TERMINATED, nan)
# 665317        (YR, 66690.0)
# 665318           (HR, 9.55)
# 665319          (HR, 16.83)
# 665320          (HR, 32.41)
# 665321        (YR, 81255.0)
# 665322          (HR, 20.95)
# 665323          (HR, 18.75)
# 665324          (HR, 16.83)
# Name: Base Salary, Length: 665325, dtype: object

# %%
# shows the unique payment types
print(data["Base Salary Payment Method"].unique())

# function to estimate hourly wages and hours worked, 
def hourly_estimates(x):
    # dictionary containing conversions of method to number of hours
    method_to_hour_estimate = {'HR': 1, 'BW': 80, 'YR': 2000, 'DA': 8, 'DAILY': 8, 
                               'AN': 2000, 'HRLY': 1, 'BM': 333.33, 'PW': 40}
    # get data from row
    method, amount_per_method, total = x["Base Salary Payment Method"], x["Base Salary Payment Amount"], x["Total Salary Paid"]
    # calc hourly wage and hours worked
    try:
        hourly_wage_estimate = amount_per_method / method_to_hour_estimate.get(method, np.nan) # if the dict does not have a conversion the default is NaN
        hours_worked_estimate = total/hourly_wage_estimate
    except ZeroDivisionError:
        hourly_wage_estimate = np.nan
        hours_worked_estimate = np.nan
    # return tuple
    return hourly_wage_estimate, hours_worked_estimate
# hour_parsed is a dataframe containing all of the hourly estimates
hour_parsed = data[["Base Salary Payment Method", "Base Salary Payment Amount", "Total Salary Paid"]] \
                    .apply(hourly_estimates, axis=1).apply(pd.Series).rename(columns={0:'Hourly Wage Estimate', 1:'Hours Worked Estimate'})  # axis one means that you apply the function on the row instead of the column
# if you were to do x.values it would give you the values of the complete row
data.insert(11, 'Hourly Wage Estimate', hour_parsed['Hourly Wage Estimate'])
data.insert(12, 'Hours Worked Estimate', hour_parsed['Hours Worked Estimate'])
# Out:
# ['HR' 'TERMINATED' 'BW' 'YR' 'DA' nan '893.00' 'DAILY' 'AN' 'ON LEAVE'
#  '-0-' 'HRLY' 'BM' 'PW' '' 'Terminated']

# %%
data.dtypes
# Out:
# Fiscal Year                   datetime64[ns]
# Department                            object
# Agency/Institution                    object
# Name                                  object
# Gender                                object
# Place of Residence                    object
# Position                              object
# Base Salary Payment Method            object
# Base Salary Payment Amount           float64
# Base Salary Date              datetime64[ns]
# Total Salary Paid                    float64
# Hourly Wage Estimate                 float64
# Hours Worked Estimate                float64
# Travel & Subsistence                 float64
# dtype: object

# %%
data
# Out:
#        Fiscal Year                               Department  \
# 0       2007-01-01  Administrative Services, Department of
# 1       2007-01-01  Administrative Services, Department of
# 2       2007-01-01  Administrative Services, Department of
# 3       2007-01-01  Administrative Services, Department of
# 4       2007-01-01  Administrative Services, Department of
# 5       2007-01-01  Administrative Services, Department of
# 6       2007-01-01  Administrative Services, Department of
# 7       2007-01-01  Administrative Services, Department of
# 8                    POLK    INFO TECH SPECIALIST 2
# 9                     NaN        EARLY OUT POSITION
# 10                  MILLS        EARLY OUT POSITION
# 11                  STORY        EARLY OUT POSITION
# 12                   POLK                EXEC OFF 4
# 13                   POLK        EARLY OUT POSITION
# 14                JACKSON        EARLY OUT POSITION
# 15                   POLK    INFO TECH SPECIALIST 5
# 16                 WARREN   DIR DEPT ADMINISTRATIVE
# 17                   POLK            CLERK-ADVANCED
# 18                   POLK   ADVANCED PERSONNEL MGMT
# 19                   POLK         INFO TECH ADMIN 1
# 20                  MILLS        EARLY OUT POSITION
# 21                   POLK   ACCOUNTING TECHNICIAN 2
# 22                   POLK          CUSTODIAL WORKER
# 23                   POLK        EARLY OUT POSITION
# 24                 HARDIN        EARLY OUT POSITION
# 25                    NaN        EARLY OUT POSITION
# 26                   POLK          CUSTODIAL WORKER
# 27                   POLK  PERSONNEL MGMT PROG COOR
# 28                  BOONE   ACCOUNTING TECHNICIAN 3
# 29                   POLK  INFO TECH ENTERPRISE EXP
# ...                   ...                       ...
# 665295      POTTAWATTAMIE                     PPFUW
# 665296      POTTAWATTAMIE         ATHLETIC DIRECTOR
# 665297      POTTAWATTAMIE                   COOK II
# 665298      POTTAWATTAMIE              SECRETARY II
# 665299              SARPY            TEMP CHAPERONE
# 665300              SARPY                   TEACHER
# 665301      POTTAWATTAMIE          SCHOOL ASSISTANT
# 665302            DOUGLAS        SPEECH PATHOLOGIST
# 665303      POTTAWATTAMIE          SCHOOL ASSISTANT
# 665304            DOUGLAS            TEMP CHAPERONE
# 665305      POTTAWATTAMIE            TEMP CHAPERONE
# 665306            DOUGLAS        SPEECH PATHOLOGIST
# 665307            DOUGLAS       ASSISTANT PRINCIPAL
# 665308              SARPY       SCHOOL PSYCHOLOGIST
# 665309              SARPY            TEMP CHAPERONE
# 665310              SARPY            TEMP CHAPERONE
# 665311            DOUGLAS            TEMP CHAPERONE
# 665312              SARPY                   TEACHER
# 665313            DOUGLAS                   TEACHER
# 665314      POTTAWATTAMIE              SECRETARY II
# 665315              SARPY           INTERPRETER SUB
# 665316      POTTAWATTAMIE                   TEACHER
# 665317      POTTAWATTAMIE  SIGN LANGUAGE INSTRUCTOR
# 665318      POTTAWATTAMIE      TEMP CLERICAL HELPER
# 665319      POTTAWATTAMIE            TEMP CHAPERONE
# 665320      POTTAWATTAMIE                     NURSE
# 665321            DOUGLAS                   TEACHER
# 665322      POTTAWATTAMIE              HOUSPARENT I
# 665323      POTTAWATTAMIE               TEACHER SUB
# 665324      POTTAWATTAMIE            TEMP CHAPERONE
#
#        Base Salary Payment Method  Base Salary Payment Amount  \
# 0                              HR                       31.62
# 1                      TERMINATED                         NaN
# 2                              BW                     2212.80
# 3                              BW                     1226.40
# 4                      TERMINATED                         NaN
# 5                      TERMINATED                         NaN
# 6                      TERMINATED                         NaN
# 7                      TERMINATED                         NaN
# 8                              BW                     2194.40
# 9                      TERMINATED                         NaN
# 10                     TERMINATED                         NaN
# 11                     TERMINATED                         NaN
# 12                             BW                     3375.20
# 13                     TERMINATED                         NaN
# 14                     TERMINATED                         NaN
# 15                             BW                     3349.60
# 16                             YR                   144200.00
# 17                             BW                     1237.60
# 18                             BW                     2908.80
# 19                             BW                     3193.60
# 20                     TERMINATED                         NaN
# 21                             BW                     1598.40
# 22                     TERMINATED                         NaN
# 23                     TERMINATED                         NaN
# 24                     TERMINATED                         NaN
# 25                     TERMINATED                         NaN
# 26                             BW                     1180.80
# 27                             BW                     3087.20
# 28                             BW                     1437.60
# 29                             BW                     4792.00
# ...                           ...                         ...
# 665295                         HR                       23.91
# 665296                         HR                    25629.00
# 665297                         HR                       22.88
# 665298                 TERMINATED                         NaN
# 665299                         HR                       16.83
# 665300                         YR                    70158.00
# 665301                         HR                       17.56
# 665302                         YR                    53638.00
# 665303                 TERMINATED                         NaN
# 665304                         HR                       16.83
# 665305                         HR                       16.83
# 665306                         YR                    81255.00
# 665307                         YR                    87138.00
# 665308                         YR                    72101.00
# 665309                         HR                       16.83
# 665310                         HR                       16.83
# 665311                         HR                       16.83
# 665312                         YR                    59663.00
# 665313                         YR                    58609.00
# 665314                         HR                       20.45
# 665315                         HR                       21.44
# 665316                 TERMINATED                         NaN
# 665317                         YR                    66690.00
# 665318                         HR                        9.55
# 665319                         HR                       16.83
# 665320                         HR                       32.41
# 665321                         YR                    81255.00
# 665322                         HR                       20.95
# 665323                         HR                       18.75
# 665324                         HR                       16.83
#
#        Base Salary Date  Total Salary Paid  Hourly Wage Estimate  \
# 0            2007-07-01            6462.34               31.6200
# 1            2007-07-01            4242.82                   NaN
# 2            2007-07-01           55065.60               27.6600
# 3            2007-07-01           30800.83               15.3300
# 4            2007-07-01           10634.33                   NaN
# 5            2007-07-01           77647.67                   NaN
# 6            2007-07-01           10520.28                   NaN
# 7            2007-07-01            2588.47                   NaN
# 8            2007-07-01           56205.58               27.4300
# 9            2007-07-01            1522.67                   NaN
# 10           2007-07-01            1645.32                   NaN
# 11           2007-07-01           11201.75                   NaN
# 12           2007-07-01            1966.08               42.1900
# 13           2007-07-01            7238.27                   NaN
# 14           2007-07-01            8669.38                   NaN
# 15           2007-07-01           87204.19               41.8700
# 16           2007-07-01          140694.27               72.1000
# 17           2007-07-01           31218.40               15.4700
# 18           2007-07-01           74780.80               36.3600
# 19           2007-07-01           82191.20               39.9200
# 20           2007-07-01            2942.86                   NaN
# 21           2007-07-01           38512.80               19.9800
# 22           2007-07-01           19357.09                   NaN
# 23           2007-07-01            8212.53                   NaN
# 24           2007-07-01            9722.32                   NaN
# 25           2007-07-01            3199.57                   NaN
# 26           2007-07-01           31786.64               14.7600
# 27           2007-07-01           86464.80               38.5900
# 28           2007-07-01           20160.00               17.9700
# 29           2007-07-01          121257.05               59.9000
# ...                 ...                ...                   ...
# 665295       2017-07-01           55021.99               23.9100
# 665296       2017-07-01           29036.00            25629.0000
# 665297       2017-07-01           37247.05               22.8800
# 665298       2017-07-01           18431.71                   NaN
# 665299       2017-07-01            1265.49               16.8300
# 665300       2017-07-01           70063.01               35.0790
# 665301       2017-07-01           28922.89               17.5600
# 665302       2017-07-01           52731.16               26.8190
# 665303       2017-07-01           21498.38                   NaN
# 665304       2017-07-01            1169.88               16.8300
# 665305       2017-07-01            9280.19               16.8300
# 665306       2017-07-01           83168.01               40.6275
# 665307       2017-07-01           86275.01               43.5690
# 665308       2017-07-01           70112.01               36.0505
# 665309       2017-07-01           11141.85               16.8300
# 665310       2017-07-01            7075.35               16.8300
# 665311       2017-07-01           10714.54               16.8300
# 665312       2017-07-01           58029.01               29.8315
# 665313       2017-07-01           57943.69               29.3045
# 665314       2017-07-01           37040.01               20.4500
# 665315       2017-07-01           12269.04               21.4400
# 665316       2017-07-01           83081.01                   NaN
# 665317       2017-07-01           65978.01               33.3450
# 665318       2017-07-01            6448.37                9.5500
# 665319       2017-07-01           12758.64               16.8300
# 665320       2017-07-01           54301.06               32.4100
# 665321       2017-07-01           81581.01               40.6275
# 665322       2017-07-01           40540.22               20.9500
# 665323       2017-07-01            1200.00               18.7500
# 665324       2017-07-01            6487.53               16.8300
#
#         Hours Worked Estimate  Travel & Subsistence
# 0                  204.375079                   NaN
# 1                         NaN                   NaN
# 2                 1990.802603                924.44
# 3                 2009.186562                  6.80
# 4                         NaN                   NaN
# 5                         NaN                364.22
# 6                         NaN                  7.48
# 7                         NaN                   NaN
# 8                 2049.055049                 65.28
# 9                         NaN                   NaN
# 10                        NaN                   NaN
# 11                        NaN                   NaN
# 12                  46.600616               2414.40
# 13                        NaN                   NaN
# 14                        NaN                   NaN
# 15                2082.736804                   NaN
# 16                1951.376838               3343.94
# 17                2017.996122                   NaN
# 18                2056.677668                612.09
# 19                2058.897796                   NaN
# 20                        NaN                   NaN
# 21                1927.567568                   NaN
# 22                        NaN                   NaN
# 23                        NaN                   NaN
# 24                        NaN                   NaN
# 25                        NaN                   NaN
# 26                2153.566396                   NaN
# 27                2240.601192               1084.30
# 28                1121.869783                 37.40
# 29                2024.324708               2398.70
# ...                       ...                   ...
# 665295            2301.212463                  0.00
# 665296               1.132935                105.05
# 665297            1627.930507                  0.00
# 665298                    NaN                  0.00
# 665299              75.192513                 73.45
# 665300            1997.292112                  0.00
# 665301            1647.089408                  0.00
# 665302            1966.186659                808.20
# 665303                    NaN                  0.00
# 665304              69.511586                  8.02
# 665305             551.407605                299.88
# 665306            2047.086579                 81.76
# 665307            1980.192568                145.60
# 665308            1944.827672                713.61
# 665309             662.023173                587.81
# 665310             420.401070                143.27
# 665311             636.633393                154.33
# 665312            1945.226019                  0.00
# 665313            1977.296661                  0.00
# 665314            1811.247433                  0.00
# 665315             572.250000                  0.00
# 665316                    NaN                  0.00
# 665317            1978.647773                 86.49
# 665318             675.221990                  0.00
# 665319             758.089127                407.64
# 665320            1675.441530                  0.00
# 665321            2008.024368                  0.00
# 665322            1935.094033                346.50
# 665323              64.000000                  0.00
# 665324             385.474153                 39.10
#
# [665325 rows x 14 columns]

# %%
print("Number of unique elements per column")
for k in ["Fiscal Year", "Department", "Agency/Institution", "Gender", "Place of Residence", "Position", "Base Salary Payment Method"]:
    c = data[k].unique()
    print(k, ":", len(c))
# Out:
# Number of unique elements per column
# ('Fiscal Year', ':', 11)
# ('Department', ':', 53)
# ('Agency/Institution', ':', 37)
# ('Gender', ':', 7)
# ('Place of Residence', ':', 1426)
# ('Position', ':', 5699)
# ('Base Salary Payment Method', ':', 16)

# %%
for k in ["Fiscal Year", "Department", "Agency/Institution", "Gender", "Place of Residence", "Position", "Base Salary Payment Method"]:
    c = data[k].value_counts()
    print(str(k)+":\n"+str(c)+"\n\n")
# Out:
# Fiscal Year:
# 2007-01-01    67695
# 2009-01-01    60328
# 2008-01-01    60262
# 2015-01-01    60138
# 2011-01-01    60125
# 2012-01-01    59929
# 2014-01-01    59859
# 2013-01-01    59488
# 2017-01-01    59400
# 2010-01-01    59113
# 2016-01-01    58988
# Name: Fiscal Year, dtype: int64
#
#
# Department:
# University of Iowa                                     235607
# Iowa State University                                  112766
# Human Services, Department of                           65299
# Transportation, Department of                           38510
# Corrections, Department of                              35940
# University of Northern Iowa                             30175
# Judicial Branch                                         21971
# Natural Resources, Department of                        17388
# Public Safety, Department of                            10917
# Iowa Veterans Home                                       9950
# Iowa Workforce Development                               9891
# Education, Department of                                 9576
# Inspections & Appeals, Department of                     6983
# Legislative Branch                                       6805
# Public Health, Department of                             6108
# Public Defense, Department of                            4866
# Agriculture & Land Stewardship, Department of            4517
# Revenue, Department of                                   4449
# Commerce, Department of                                  4212
# Administrative Services, Department of                   3585
# Regents, Board of                                        3533
# Attorney General, Office of                              3060
# Veterans Affairs, Department of                          2521
# Administrative Services, Department of                   1587
# Auditor of State, Office of                              1409
# Iowa Lottery Authority                                   1404
# Iowa Finance Authority                                   1225
# Blind, Department for the                                1090
# Iowa Communications Network                              1056
# Cultural Affairs, Department of                          1042
# IPERS                                                     944
# Iowa Economic Development Authority                       908
# Economic Development, Department of                       812
# Human Rights, Department of                               651
# Iowa Student College Aid Commission                       573
# Secretary of State, Office of                             463
# Governor, Office of                                       459
# Iowa Civil Rights Commission                              449
# Chief Information Officer, Office of                      382
# Law Enforcement Academy                                   347
# Treasurer of State, Office of                             337
# Aging, Department on                                      324
# Management, Department of                                 320
# Parole, Board of                                          203
# Homeland Security & Emergency Management Department       168
# Public Employment Relations Board                         127
# Elder Affairs, Department of                              122
# Ethics & Campaign Disclosure Board                         88
# Energy Independence, Office of                             85
# Drug Control Policy, Office of                             75
# Rebuild Iowa Office                                        24
# Public Information Board                                   13
# Governor-Elect, Office of                                   9
# Name: Department, dtype: int64
#
#
# Agency/Institution:
# Univ. Of Iowa Hospital & Clinics                87279
# Human Services Administration                   33741
# Human Services Glenwood                         10914
# Human Services Woodward                          8633
# Corrections IA Medical Classification Center     6542
# Corrections Fort Madison                         5634
# Corrections Anamosa                              4040
# Corrections Fort Dodge                           3757
# Corrections Newton                               3616
# Corrections Mt Pleasant                          3515
# PUBLIC SERVICE EXECUTIVE              3484
# SLIP RETIREE                          3403
# Secretary II                          3377
# WORKFORCE ADVISOR                     3369
# Postdoctoral Research Scholar         3293
# LECTURER                              3198
# Clinical Assistant Professor          3157
# Misc Temporary(Non-Student)           3024
# ASST PROF                             2983
# SECRETARY 2                           2846
#                                      ...
# S PROGRAM ASSISTANT                      1
# UNIV RISK MGR                            1
# E PROFESSOR                              1
# Electrician, High Voltage Tr             1
# LIEUTENANT GOVERNOR            10        1
# M UNCLASSIFIED STAFF                     1
# GIFT PROC CLERK                          1
# SENATE DEMOCRATIC FLOOR         3        1
# ASSOC DIRECTOR ENGINEE                   1
# SECRETARY OF AGRICULTURE       10        1
# Clinical Veterinarian                    1
# MEDICAL RECORDS ADMINI                   1
# DIRECTOR OF CAMPAIGNS                    1
# EXEC DIR/FINANCE AUTHORI       12        1
# SHEET MTL MECH I                         1
# OCC SAFE SPEC III                        1
# ASST DIR BUSINESS OPER                   1
# CENT SERV TECH I                         1
# MANAGER/WEB & BI SYSTE                   1
# DIR OF APPELLATE SCREENI                 1
# BUDGET ANALYST V                         1
# ACADEMIC ADVISOR/COE L                   1
# Junior Staff Psychologist                1
# SUB-TECH SPECIALIST                      1
# HUMAN SERVICES ADMIN FIE                 1
# UT PL MNT MECH I                         1
# MEDIA PROD SPEC II                       1
# G INSTRUCTOR                             1
# INST OFFICIAL                            1
# COMP PUBLISH SPEC                        1
# Name: Position, Length: 5698, dtype: int64
#
#
# Base Salary Payment Method:
# BW            222943
# TERMINATED     41706
# HR             21943
# -0-            14655
# YR              7834
# DA              2190
# HRLY             106
# AN                86
# DAILY             64
# ON LEAVE          50
#                   47
# Terminated        32
# PW                 2
# BM                 1
# 893.00             1
# Name: Base Salary Payment Method, dtype: int64

# %%
# Import data for each area in Iowa
residenceDataFile = "residenceData.csv"
residenceData = pd.read_csv(residenceDataFile, parse_dates=['Fiscal Year'])
print(residenceData)
# Out:
#       Place of Residence Fiscal Year  adult_obesity_value  \
# 0             CLARE CITY  2016-01-01                  NaN
# 1             CLARE CITY  2017-01-01                  NaN
# 2             CLARE CITY  2007-01-01                  NaN
# 3             CLARE CITY  2008-01-01                  NaN
# 4             CLARE CITY  2009-01-01                  NaN
# 5             CLARE CITY  2010-01-01                  NaN
# 6             CLARE CITY  2011-01-01                  NaN
# 7             CLARE CITY  2012-01-01                  NaN
# 8             CLARE CITY  2013-01-01                  NaN
# 9             CLARE CITY  2014-01-01                  NaN
# 10            CLARE CITY  2015-01-01                  NaN
# 11            DERBY CITY  2016-01-01                  NaN
# 12            DERBY CITY  2017-01-01                  NaN
# 13            DERBY CITY  2007-01-01                  NaN
# 14            DERBY CITY  2008-01-01                  NaN
# 15            DERBY CITY  2009-01-01                  NaN
# 16            DERBY CITY  2010-01-01                  NaN
# 17            DERBY CITY  2011-01-01                  NaN
# 18            DERBY CITY  2012-01-01                  NaN
# 19            DERBY CITY  2013-01-01                  NaN
# 20            DERBY CITY  2014-01-01                  NaN
# 12306                            NaN                 NaN                 NaN
# 12307                            NaN                 NaN                 NaN
# 12308                            NaN                 NaN                 NaN
#
#        violent_crime_value  uninsured_value   density  \
# 0                      NaN              NaN   436.278
# 1                      NaN              NaN   436.278
# 2                      NaN              NaN   240.842
# 3                      NaN              NaN   240.842
# 4                      NaN              NaN   240.842
# 5                      NaN              NaN   223.075
# 6                      NaN              NaN   290.194
# 7                      NaN              NaN   321.780
# 8                      NaN              NaN   331.651
# 9                      NaN              NaN   375.081
# 10                     NaN              NaN   457.994
# 11                     NaN              NaN   511.397
# 12                     NaN              NaN   511.397
# 13                     NaN              NaN   649.820
# 14                     NaN              NaN   649.820
# 15                     NaN              NaN   649.820
# 16                     NaN              NaN   480.636
# 17                     NaN              NaN   446.031
# 18                     NaN              NaN   419.115
# 19                     NaN              NaN   472.946
# 20                     NaN              NaN   396.044
# 21                     NaN              NaN   507.552
# 22                     NaN              NaN  1014.073
# 23                     NaN              NaN  1014.073
# 24                     NaN              NaN  1089.311
# 25                     NaN              NaN  1089.311
# 26                     NaN              NaN  1089.311
# 27                     NaN              NaN  1285.583
# 28                     NaN              NaN  1243.057
# 29                     NaN              NaN  1167.819
# ...                    ...              ...       ...
# 12279                  NaN              NaN   661.450
# 12280                  NaN              NaN   661.450
# 12281                  NaN              NaN   749.199
# 12282                  NaN              NaN   793.074
# 12283                  NaN              NaN   753.087
# 12284                  NaN              NaN   775.302
# 12285                  NaN              NaN   719.764
# 12286                  NaN              NaN   711.434
# 12287                  NaN              NaN   952.413
# 12288                  NaN              NaN   952.413
# 12289                  NaN              NaN   968.240
# 12290                  NaN              NaN   968.240
# 12291                  NaN              NaN   968.240
# 12292                  NaN              NaN   927.276
# 12293                  NaN              NaN   993.377
# 12294                  NaN              NaN  1000.825
# 12295                  NaN              NaN  1101.373
# 12296                  NaN              NaN   960.792
# 12297                  NaN              NaN   976.619
# 12298                  NaN              NaN   247.831
# 12299                  NaN              NaN   247.831
# 12300                  NaN              NaN   249.109
# 12301                  NaN              NaN   249.109
# 12302                  NaN              NaN   249.109
# 12303                  NaN              NaN   235.057
# 12304                  NaN              NaN   242.721
# 12305                  NaN              NaN   255.496
# 12306                  NaN              NaN   246.554
# 12307                  NaN              NaN   275.936
# 12308                  NaN              NaN   260.606
#
#        percent_graduate_or_professional_degree  percent_some_college  \
# 0                                          0.0                  19.5
# 1                                          0.0                  19.5
# 2                                          2.4                  19.5
# 3                                          2.4                  19.5
# 4                                          2.4                  19.5
# 5                                          2.4                  19.5
# 6                                          2.0                  19.5
# 7                                          1.7                  19.5
# 8                                          0.0                  19.5
# 9                                          0.0                  19.5
# 10                                         0.0                  19.5
# 11                                         0.0                  50.5
# 12                                         0.0                  50.5
# 13                                         0.0                  50.5
# 14                                         0.0                  50.5
# 15                                         0.0                  50.5
# 16                                         0.0                  50.5
# 17                                         0.0                  50.5
# 18                                         0.0                  50.5
# 19                                         0.0                  50.5
# 20                                         0.0                  50.5
# 21                                         0.0                  50.5
# 22                                         1.0                  30.7
# 23                                         1.0                  30.7
# 24                                         0.0                  30.7
# 25                                         0.0                  30.7
# 26                                         0.0                  30.7
# 27                                         0.0                  30.7
# 28                                         2.1                  30.7
# 29                                         2.9                  30.7
# ...                                        ...                   ...
# 12279                                      3.7                  25.8
# 12280                                      3.7                  25.8
# 12281                                      3.7                  25.8
# 12282                                      3.2                  25.8
# 12283                                      3.1                  25.8
# 12284                                      2.8                  25.8
# 12285                                      2.7                  25.8
# 12286                                      4.0                  25.8
# 12287                                      5.8                  25.1
# 12288                                      5.8                  25.1
# 12289                                      6.8                  25.1
# 12290                                      6.8                  25.1
# 12291                                      6.8                  25.1
# 12292                                      6.8                  25.1
# 12293                                      4.8                  25.1
# 12294                                      4.3                  25.1
# 12295                                      5.1                  25.1
# 12296                                      4.2                  25.1
# 12297                                      6.4                  25.1
# 12298                                      2.9                  14.8
# 12299                                      2.9                  14.8
# 12300                                      0.0                  14.8
# 12301                                      0.0                  14.8
# 12302                                      0.0                  14.8
# 12303                                      0.0                  14.8
# 12304                                      0.7                  14.8
# 12305                                      0.0                  14.8
# 12306                                      0.0                  14.8
# 12307                                      1.3                  14.8
# 12308                                      2.2                  14.8
#
#        percent_less_than_9th_grade  percent_associates_degree  \
# 0                              2.6                       25.8
# 1                              2.6                       25.8
# 2                              8.2                       10.6
# 3                              8.2                       10.6
# 4                              8.2                       10.6
# 5                              8.2                       10.6
# 6                              3.1                       19.4
# 7                              1.7                       22.5
# 8                              1.7                       28.0
# 9                              2.2                       31.3
# 10                             2.0                       33.6
# 11                             7.8                       15.6
# 12                             7.8                       15.6
# 13                             2.3                        5.7
# 14                             2.3                        5.7
# 15                             2.3                        5.7
# 16                             2.3                        5.7
# 17                             0.0                        4.2
# 18                             2.6                        5.1
# 19                             3.3                       14.3
# 20                             5.7                       18.6
# 21                             7.7                       13.2
# 22                             1.0                       14.4
# 23                             1.0                       14.4
# 24                             9.5                       10.7
# 25                             9.5                       10.7
# 26                             9.5                       10.7
# 27                             9.5                       10.7
# 28                             8.8                        9.2
# 29                             9.6                        8.4
# ...                            ...                        ...
# 12279                          4.7                        8.1
# 12280                          4.7                        8.1
# 12281                          4.7                        8.1
# 12282                          7.8                       10.6
# 12283                          6.2                       15.1
# 12284                          6.6                       11.7
# 12285                          6.3                       14.9
# 12286                          3.8                       16.8
# 12287                          5.1                       19.2
# 12288                          5.1                       19.2
# 12289                          7.2                       12.3
# 12290                          7.2                       12.3
# 12291                          7.2                       12.3
# 12292                          7.2                       12.3
# 12293                          7.8                        8.7
# 12294                          6.2                       13.9
# 12295                          5.1                       14.3
# 12296                          7.7                       15.5
# 12297                          3.9                       15.7
# 12298                          3.7                        5.9
# 12299                          3.7                        5.9
# 12300                          3.6                        7.2
# 12301                          3.6                        7.2
# 12302                          3.6                        7.2
# 12303                          3.6                        7.2
# 12304                          2.1                        9.1
# 12305                          2.1                        8.6
# 12306                          2.2                        7.4
# 12307                          3.4                        5.4
# 12308                          4.4                        3.6
#
#        percent_bachelors_degree_or_higher  percent_high_school_graduate  count
# 0                                     9.7                          39.8    221
# 1                                     9.7                          39.8    221
# 2                                     9.4                          39.8    122
# 3                                     9.4                          39.8    122
# 4                                     9.4                          39.8    122
# 5                                     9.4                          39.8    113
# 6                                     8.2                          39.8    147
# 7                                     6.7                          39.8    163
# 8                                     7.6                          39.8    168
# 9                                    10.4                          39.8    190
# 10                                    9.4                          39.8    232
# 11                                    2.2                          26.4    133
# 12                                    2.2                          26.4    133
# 13                                   11.4                          26.4    169
# 14                                   11.4                          26.4    169
# 15                                   11.4                          26.4    169
# 16                                   11.4                          26.4    125
# 17                                   12.5                          26.4    116
# 18                                    3.8                          26.4    109
# 19                                    1.1                          26.4    123
# 20                                    1.4                          26.4    103
# 21                                    2.2                          26.4    132
# 22                                    7.7                          32.7    310
# 23                                    7.7                          32.7    310
# 24                                   11.1                          32.7    333
# 25                                   11.1                          32.7    333
# 26                                   11.1                          32.7    333
# 27                                   11.1                          32.7    393
# 28                                   18.1                          32.7    380
# 29                                   18.4                          32.7    357
# ...                                   ...                           ...    ...
# 12279                                16.6                          35.1   1191
# 12280                                16.6                          35.1   1191
# 12281                                16.6                          35.1   1349
# 12282                                16.0                          35.1   1428
# 12283                                12.6                          35.1   1356
# 12284                                13.3                          35.1   1396
# 12285                                13.6                          35.1   1296
# 12286                                16.5                          35.1   1281
# 12287                                17.8                          30.0   1023
# 12288                                17.8                          30.0   1023
# 12289                                24.4                          30.0   1040
# 12290                                24.4                          30.0   1040
# 12291                                24.4                          30.0   1040
# 12292                                24.4                          30.0    996
# 12293                                20.1                          30.0   1067
# 12294                                20.3                          30.0   1075
# 12295                                20.7                          30.0   1183
# 12296                                14.8                          30.0   1032
# 12297                                19.1                          30.0   1049
# 12298                                15.4                          51.9    194
# 12299                                15.4                          51.9    194
# 12300                                11.6                          51.9    195
# 12301                                11.6                          51.9    195
# 12302                                11.6                          51.9    195
# 12303                                11.6                          51.9    184
# 12304                                15.4                          51.9    190
# 12305                                15.7                          51.9    200
# 12306                                19.3                          51.9    193
# 12307                                15.4                          51.9    216
# 12308                                16.8                          51.9    204
#
# [12309 rows x 18 columns]

# %%
residenceData[residenceData['adult_obesity_value'].notnull()]
# Out:
#       Place of Residence Fiscal Year  adult_obesity_value  \
# 66             ALLAMAKEE  2016-01-01                0.295
# 67             ALLAMAKEE  2017-01-01                0.295
# 68             ALLAMAKEE  2007-01-01                0.295
# 69             ALLAMAKEE  2008-01-01                0.295
# 70             ALLAMAKEE  2009-01-01                0.295
# 71             ALLAMAKEE  2010-01-01                0.295
# 72             ALLAMAKEE  2011-01-01                0.295
# 73             ALLAMAKEE  2012-01-01                0.295
# 74             ALLAMAKEE  2013-01-01                0.295
# 75             ALLAMAKEE  2014-01-01                0.295
# 76             ALLAMAKEE  2015-01-01                0.295
# 77               JOHNSON  2016-01-01                0.235
# 78               JOHNSON  2017-01-01                0.235
# 79               JOHNSON  2007-01-01                0.235
# 12269                        50342.0               0.539               0.047
# 12270                        50342.0               0.539               0.047
# 12271                        50342.0               0.539               0.047
# 12272                        50342.0               0.539               0.047
# 12273                        50342.0               0.539               0.047
# 12274                        50342.0               0.539               0.047
# 12275                        50342.0               0.539               0.047
#
#        violent_crime_value  uninsured_value  density  \
# 66                     NaN            0.140   21.908
# 67                     NaN            0.140   21.908
# 68                     NaN            0.140   22.565
# 69                     NaN            0.140   22.565
# 70                     NaN            0.140   22.565
# 71                     NaN            0.140   22.424
# 72                     NaN            0.140   22.390
# 73                     NaN            0.140   22.352
# 74                     NaN            0.140   22.285
# 75                     NaN            0.140   22.144
# 76                     NaN            0.140   22.000
# 77                  235.86            0.094  231.265
# 78                  235.86            0.094  231.265
# 79                  235.86            0.094  204.889
# 80                  235.86            0.094  204.889
# 81                  235.86            0.094  204.889
# 82                  235.86            0.094  206.817
# 83                  235.86            0.094  210.343
# 84                  235.86            0.094  214.362
# 85                  235.86            0.094  218.282
# 86                  235.86            0.094  222.790
# 87                  235.86            0.094  227.080
# 154                 123.48            0.100   12.232
# 155                 123.48            0.100   12.232
# 156                 123.48            0.100   13.121
# 157                 123.48            0.100   13.121
# 158                 123.48            0.100   13.121
# 159                 123.48            0.100   13.008
# 160                 123.48            0.100   12.832
# 161                 123.48            0.100   12.658
# ...                    ...              ...      ...
# 12180               107.30            0.095   27.054
# 12181               107.30            0.095   27.054
# 12182               107.30            0.095   27.372
# 12183               107.30            0.095   27.197
# 12184               107.30            0.095   26.967
# 12185               107.30            0.095   26.797
# 12186               107.30            0.095   26.580
# 12187               107.30            0.095   26.503
# 12254               430.48            0.114   98.176
# 12255               430.48            0.114   98.176
# 12256               430.48            0.114   97.031
# 12257               430.48            0.114   97.031
# 12258               430.48            0.114   97.031
# 12259               430.48            0.114   97.152
# 12260               430.48            0.114   97.456
# 12261               430.48            0.114   97.673
# 12262               430.48            0.114   97.831
# 12263               430.48            0.114   97.966
# 12264               430.48            0.114   98.094
# 12265                64.02            0.108   24.117
# 12266                64.02            0.108   24.117
# 12267                64.02            0.108   24.109
# 12268                64.02            0.108   24.109
# 12269                64.02            0.108   24.109
# 12270                64.02            0.108   24.781
# 12271                64.02            0.108   24.723
# 12272                64.02            0.108   24.602
# 12273                64.02            0.108   24.543
# 12274                64.02            0.108   24.444
# 12275                64.02            0.108   24.275
#
#        percent_graduate_or_professional_degree  percent_some_college  \
# 66                                         4.8                  21.3
# 67                                         4.8                  21.3
# 68                                         3.7                  21.3
# 69                                         3.7                  21.3
# 70                                         3.7                  21.3
# 71                                         3.7                  21.3
# 72                                         3.8                  21.3
# 73                                         3.5                  21.3
# 74                                         3.9                  21.3
# 75                                         4.5                  21.3
# 76                                         4.7                  21.3
# 77                                        24.4                  17.7
# 78                                        24.4                  17.7
# 79                                        23.1                  17.7
# 80                                        23.1                  17.7
# 81                                        23.1                  17.7
# 82                                        23.1                  17.7
# 83                                        22.8                  17.7
# 84                                        23.2                  17.7
# 85                                        23.7                  17.7
# 86                                        24.1                  17.7
# 87                                        24.0                  17.7
# 154                                        2.9                  21.9
# 155                                        2.9                  21.9
# 156                                        4.3                  21.9
# 157                                        4.3                  21.9
# 158                                        4.3                  21.9
# 159                                        4.3                  21.9
# 160                                        4.2                  21.9
# 161                                        3.5                  21.9
# ...                                        ...                   ...
# 12180                                      5.5                  25.4
# 12181                                      5.5                  25.4
# 12182                                      5.5                  25.4
# 12183                                      5.4                  25.4
# 12184                                      4.8                  25.4
# 12185                                      3.8                  25.4
# 12186                                      4.9                  25.4
# 12187                                      4.7                  25.4
# 12254                                      6.1                  23.9
# 12255                                      6.1                  23.9
# 12256                                      6.5                  23.9
# 12257                                      6.5                  23.9
# 12258                                      6.5                  23.9
# 12259                                      6.5                  23.9
# 12260                                      5.5                  23.9
# 12261                                      4.9                  23.9
# 12262                                      4.5                  23.9
# 12263                                      5.3                  23.9
# 12264                                      5.3                  23.9
# 12265                                      3.9                  19.3
# 12266                                      3.9                  19.3
# 12267                                      3.2                  19.3
# 12268                                      3.2                  19.3
# 12269                                      3.2                  19.3
# 12270                                      3.2                  19.3
# 12271                                      3.1                  19.3
# 12272                                      3.6                  19.3
# 12273                                      3.8                  19.3
# 12274                                      3.7                  19.3
# 12275                                      3.8                  19.3
#
#        percent_less_than_9th_grade  percent_associates_degree  \
# 66                             6.2                       10.8
# 67                             6.2                       10.8
# 68                             6.8                        9.3
# 69                             6.8                        9.3
# 70                             6.8                        9.3
# 71                             6.8                        9.3
# 72                             6.9                        9.5
# 73                             6.3                        9.8
# 74                             5.7                        9.0
# 75                             5.9                        8.7
# 76                             6.3                        9.3
# 77                             2.7                        8.6
# 78                             2.7                        8.6
# 79                             2.4                        8.5
# 80                             2.4                        8.5
# 81                             2.4                        8.5
# 82                             2.4                        8.5
# 83                             2.1                        8.7
# 84                             2.1                        8.7
# 85                             2.4                        9.0
# 86                             2.5                        8.9
# 87                             2.6                        8.9
# 154                            2.9                       14.3
# 155                            2.9                       14.3
# 156                            3.3                       11.2
# 157                            3.3                       11.2
# 158                            3.3                       11.2
# 159                            3.3                       11.2
# 160                            3.5                       10.8
# 161                            3.6                       11.7
# ...                            ...                        ...
# 12180                          2.7                       10.9
# 12181                          2.7                       10.9
# 12182                          2.7                       10.9
# 12183                          2.9                       10.0
# 12184                          3.4                       10.2
# 12185                          2.5                       11.4
# 12186                          2.2                       11.8
# 12187                          2.3                       12.7
# 12254                          6.2                       12.0
# 12255                          6.2                       12.0
# 12256                          7.3                       10.5
# 12257                          7.3                       10.5
# 12258                          7.3                       10.5
# 12259                          7.3                       10.5
# 12260                          6.4                       10.0
# 12261                          6.7                       10.5
# 12262                          7.5                       10.7
# 12263                          7.0                       10.5
# 12264                          6.4                       11.5
# 12265                          4.1                       14.5
# 12266                          4.1                       14.5
# 12267                          5.9                        9.3
# 12268                          5.9                        9.3
# 12269                          5.9                        9.3
# 12270                          5.9                        9.3
# 12271                          5.8                        9.7
# 12272                          5.3                       10.0
# 12273                          5.0                       10.2
# 12274                          4.9                       11.9
# 12275                          4.5                       13.0
#
#        percent_bachelors_degree_or_higher  percent_high_school_graduate  \
# 66                                   17.0                          43.8
# 67                                   17.0                          43.8
# 68                                   13.5                          43.8
# 69                                   13.5                          43.8
# 70                                   13.5                          43.8
# 71                                   13.5                          43.8
# 72                                   15.3                          43.8
# 73                                   13.8                          43.8
# 74                                   14.9                          43.8
# 75                                   15.9                          43.8
# 76                                   16.3                          43.8
# 77                                   52.4                          17.0
# 78                                   52.4                          17.0
# 79                                   50.8                          17.0
# 80                                   50.8                          17.0
# 81                                   50.8                          17.0
# 82                                   50.8                          17.0
# 83                                   50.6                          17.0
# 84                                   51.2                          17.0
# 85                                   51.1                          17.0
# 86                                   51.7                          17.0
# 87                                   51.3                          17.0
# 154                                  16.9                          40.3
# 155                                  16.9                          40.3
# 156                                  16.4                          40.3
# 157                                  16.4                          40.3
# 158                                  16.4                          40.3
# 159                                  16.4                          40.3
# 160                                  17.3                          40.3
# 161                                  17.5                          40.3
# ...                                   ...                           ...
# 12180                                19.3                          36.5
# 12181                                19.3                          36.5
# 12182                                19.3                          36.5
# 12183                                20.8                          36.5
# 12184                                19.7                          36.5
# 12185                                18.6                          36.5
# 12186                                21.3                          36.5
# 12187                                20.6                          36.5
# 12254                                20.5                          33.9
# 12255                                20.5                          33.9
# 12256                                19.8                          33.9
# 12257                                19.8                          33.9
# 12258                                19.8                          33.9
# 12259                                19.8                          33.9
# 12260                                18.0                          33.9
# 12261                                16.9                          33.9
# 12262                                16.2                          33.9
# 12263                                18.2                          33.9
# 12264                                18.8                          33.9
# 12265                                14.5                          45.5
# 12266                                14.5                          45.5
# 12267                                13.5                          45.5
# 12268                                13.5                          45.5
# 12269                                13.5                          45.5
# 12270                                13.5                          45.5
# 12271                                14.4                          45.5
# 12272                                14.9                          45.5
# 12273                                13.8                          45.5
# 12274                                14.5                          45.5
# 12275                                15.0                          45.5
#
#         count
# 66      14001
# 67      14001
# 68      14421
# 69      14421
# 70      14421
# 71      14331
# 72      14309
# 73      14285
# 74      14242
# 75      14152
# 76      14060
# 77     142006
# 78     142006
# 79     125810
# 80     125810
# 81     125810
# 82     126994
# 83     129159
# 84     131627
# 85     134034
# 86     136802
# 87     139436
# 154      7061
# 155      7061
# 156      7574
# 157      7574
# 158      7574
# 159      7509
# 160      7407
# 161      7307
# ...       ...
# 12180   10835
# 12181   10835
# 12182   10962
# 12183   10892
# 12184   10800
# 12185   10732
# 12186   10645
# 12187   10614
# 12254   42949
# 12255   42949
# 12256   42448
# 12257   42448
# 12258   42448
# 12259   42501
# 12260   42634
# 12261   42729
# 12262   42798
# 12263   42857
# 12264   42913
# 12265   12164
# 12266   12164
# 12267   12160
# 12268   12160
# 12269   12160
# 12270   12499
# 12271   12470
# 12272   12409
# 12273   12379
# 12274   12329
# 12275   12244
#
# [1089 rows x 18 columns]

# %%
# Merge data and residence data into new dataframe
fullData = pd.merge(data, residenceData, on=["Place of Residence", "Fiscal Year"])
print(fullData.columns.values)
print(fullData)
# Out:
# ['Fiscal Year' 'Department' 'Agency/Institution' 'Name' 'Gender'
#  'Place of Residence' 'Position' 'Base Salary Payment Method'
#  'Base Salary Payment Amount' 'Base Salary Date' 'Total Salary Paid'
#  'Hourly Wage Estimate' 'Hours Worked Estimate' 'Travel & Subsistence'
#  'adult_obesity_value' 'children_in_poverty_value'
#  'income_inequality_value' 'median_household_income_value'
#  'some_college_value' 'unemployment_value' 'violent_crime_value'
#  'uninsured_value' 'density' 'percent_graduate_or_professional_degree'
#  'percent_some_college' 'percent_less_than_9th_grade'
#  'percent_associates_degree' 'percent_bachelors_degree_or_higher'
#  'percent_high_school_graduate' 'count']
#        Fiscal Year                               Department  \
# 0       2007-01-01  Administrative Services, Department of
# 1       2007-01-01  Administrative Services, Department of
# 2       2007-01-01  Administrative Services, Department of
# 3       2007-01-01  Administrative Services, Department of
# 4       2007-01-01  Administrative Services, Department of
# 5       2007-01-01  Administrative Services, Department of
# 6       2007-01-01  Administrative Services, Department of
# 7       2007-01-01  Administrative Services, Department of
# 8       2007-01-01  Administrative Services, Department of
# 9       2007-01-01  Administrative Services, Department of
# 10      2007-01-01  Administrative Services, Department of
# 11      2007-01-01  Administrative Services, Department of
# 12      2007-01-01  Administrative Services, Department of
# 13      2007-01-01  Administrative Services, Department of
# 14      2007-01-01  Administrative Services, Department of
# 15      2007-01-01  Administrative Services, Department of
# 16      2007-01-01  Administrative Services, Department of
# 17      2007-01-01  Administrative Services, Department of
# 18      2007-01-01  Administrative Services, Department of
# 19      2007-01-01  Administrative Services, Department of
# 20      2007-01-01  Administrative Services, Department of
# 21      2007-01-01  Administrative Services, Department of
# 22      2007-01-01  Administrative Services, Department of
# 23      2007-01-01  Administrative Services, Department of
# 24      2007-01-01  Administrative Services, Department of
# 25      2007-01-01  Administrative Services, Department of
# 26      2007-01-01  Administrative Services, Department of
# 27      2007-01-01  Administrative Services, Department of
# 28      2007-01-01  Administrative Services, Department of
# 29      2007-01-01  Administrative Services, Department of
# ...            ...                                      ...
# 627495  2017-01-01            Transportation, Department of
# 627496  2017-01-01            Transportation, Department of
# 627497  2017-01-01            Transportation, Department of
# 627498  2017-01-01            Transportation, Department of
# 627499  2017-01-01            Transportation, Department of
# 627500  2017-01-01            Transportation, Department of
# 627501  2017-01-01            Transportation, Department of
# 627502  2017-01-01            Transportation, Department of
# 627503  2017-01-01            Transportation, Department of
# 627504  2017-01-01            Transportation, Department of
# 627505  2017-01-01            Transportation, Department of
# 627506  2017-01-01            Transportation, Department of
# 627507  2017-01-01            Transportation, Department of
# 627508  2017-01-01            Transportation, Department of
# 627509  2017-01-01            Transportation, Department of
# 627510  2017-01-01            Transportation, Department of
# 627511  2017-01-01            Transportation, Department of
# 627512  2017-01-01            Transportation, Department of
# 627513  2017-01-01                       University of Iowa
# 627514  2017-01-01                       University of Iowa
# 627515  2017-01-01                       University of Iowa
# 627516  2017-01-01               Iowa Workforce Development
# 627517  2017-01-01               Iowa Workforce Development
# 627518  2017-01-01                        Regents, Board of
# 627519  2017-01-01                        Regents, Board of
# 627520  2017-01-01                        Regents, Board of
# 627521  2017-01-01                        Regents, Board of
# 627522  2017-01-01                        Regents, Board of
# 627523  2017-01-01                       University of Iowa
# 627524  2017-01-01            Transportation, Department of
#
#                         Agency/Institution                    Name Gender  \
# 0                                      NaN         ABELS BEVERLY J      F
# 1                                      NaN         ADAMS JEANNIE R      F
# 2                                      NaN             ADAMS NED J      M
# 3                                      NaN         ADAMSON DAVID A      M
# 4                                      NaN          ALLEN DANIEL S      M
# 5                                      NaN          ALLEN SANDRA L      F
# 6                                      NaN         ANDERSON BRAD M      M
# 7                                      NaN        ANDERSON JAMES D      M
# 8                                      NaN      ANDERSON KENNETH L      M
# 9                                      NaN     ANDERSON RANDOLPH G      M
# 10                                     NaN       ANDERSON VICKIE L      F
# 11                                     NaN       ANDERSON VICTOR N      M
# 12                                     NaN          ANSTEY LYNN M.      F
# 13                                     NaN        ARMOUR KENNETH D      M
# 14                                     NaN       ARVIDSON GEORGE A      M
# 15                                     NaN   AVRITT GORDON DOUGLAS      M
# 16                                     NaN          AXNE CYNTHIA L      F
# 17                                     NaN        BABCOCK DENNIS S      M
# 18                                     NaN           BAER JOSEPH A      M
# 19                                     NaN          BANKER CRAIG D      M
# 20                                     NaN         BARTELT EDWIN L      M
# 21                                     NaN     BASSETT CHRISTINE A      F
# 22                                     NaN      BAUGHMAN ROSALYN K      F
# 23                                     NaN      BAXTER JACQUELYN L      F
# 24                                     NaN         BECHTEL VINCENT      M
# 25                                     NaN           BECK DANIEL H      M
# 26                                     NaN         BEERY DERRICK S      M
# 27                                     NaN       BEHRENS MATTHEW N      M
# 28                                     NaN        BELL GENEVIEVE K      F
# 29                                     NaN        BENNETHUM DALE R      M
# ...                                    ...                     ...    ...
# 627495                                 NaN     HENSLEY, NICHOLAS L      M
# 627496                                 NaN          HOCAMP, PAUL A      M
# 627497                                 NaN        IHNEN, WILLIAM J      M
# 627498                                 NaN         JORDAN, JAMES K      M
# 627499                                 NaN     KIRCHHOFF, DWAINE P      M
# 627500                                 NaN    KIRCHHOFF, JEFFREY L      M
# 627501                                 NaN             MAES, AMY J      F
# 627502                                 NaN       MAGERS, MICHAEL W      M
# 627503                                 NaN          MEADS, JAMES B      M
# 627504                                 NaN         MURRAY, JAMES A      M
# 627505                                 NaN           RINK, BRIAN T      M
# 627506                                 NaN    SANDBOTHE, DOUGLAS J      M
# 627507                                 NaN        SHRIVER, CRAIG L      M
# 627508                                 NaN         SNYDER, JULIA K      F
# 627509                                 NaN         STEFFEN, NATHAN      M
# 627510                                 NaN       THOMPSON, RICKY D      M
# 627511                                 NaN       THOMSEN, BARNEY D      M
# 627512                                 NaN          WATERS, TODD J      M
# 627513                                 NaN  POLASEK, TIMOTHY ALLEN      M
# 627514                                 NaN      WALLINGFORD, TYLER      M
# 627515    Univ. Of Iowa Hospital & Clinics          DUNCAN, JACLYN      F
# 627516                                 NaN      PANIAGUA CASSIE JO      F
# 627517                                 NaN         TUPPER ALISON D      F
# 627518            Iowa School For The Deaf             AMOS, CAROL      F
# 627519            Iowa School For The Deaf          ARTEAGA, DAVID      M
# 627520            Iowa School For The Deaf       ARTEAGA, JONATHAN      M
# 627521            Iowa School For The Deaf         RISHEL, DOUGLAS      M
# 627522  Iowa Braille & Sight Saving School      BERKENPAS, MARY A.      F
# 627523                                 NaN            LIEN, TAYLOR      F
# 627524                                 NaN        EIKAMP, JORDAN C      M
#
#        Place of Residence                      Position  \
# 0                    POLK       ADVANCED PERSONNEL MGMT
# 1                    POLK       ACCOUNTING TECHNICIAN 2
# 2                    POLK            EARLY OUT POSITION
# 3                    POLK      CONSTRUCTION/DESIGN ENGN
# 4                    POLK              CUSTODIAL WORKER
# 5                    POLK        INFO TECH SPECIALIST 2
# 6                    POLK                    EXEC OFF 4
# 7                    POLK            EARLY OUT POSITION
# 8                    POLK        INFO TECH SPECIALIST 5
# 9                    POLK                CLERK-ADVANCED
# 10                   POLK       ADVANCED PERSONNEL MGMT
# 11                   POLK             INFO TECH ADMIN 1
# 12                   POLK       ACCOUNTING TECHNICIAN 2
# 13                   POLK              CUSTODIAL WORKER
# 14                   POLK            EARLY OUT POSITION
# 15                   POLK              CUSTODIAL WORKER
# 16                   POLK      PERSONNEL MGMT PROG COOR
# 17                   POLK      INFO TECH ENTERPRISE EXP
# 18                   POLK            EARLY OUT POSITION
# 19                   POLK               HVAC TECHNICIAN
# 20                   POLK            EARLY OUT POSITION
# 21                   POLK                  SLIP RETIREE
# 22                   POLK       ADVANCED PERSONNEL MGMT
# 23                   POLK        INFO TECH SPECIALIST 4
# 24                   POLK        INFO TECH SPECIALIST 5
# 25                   POLK      REPRODUCTION EQUIPMENT O
# 26                   POLK        INFO TECH SPECIALIST 5
# 27                   POLK      INFO TECH ENTERPRISE EXP
# 28                   POLK            EARLY OUT POSITION
# 29                   POLK          MAINTENANCE WORKER 2
# ...                   ...                           ...
# 627495               CASS                    TRANS AIDE
# 627496               CASS                    TRANS AIDE
# 627497               CASS                  MTL FAB IN 1
# 627498               CASS                   ENG TECH SR
# 627499               CASS                  HT ASSOCIATE
# 627500               CASS                  HIGHWAY TECH
# 627501               CASS                  CON TEC ASST
# 627502               CASS                    MTL TECH 5
# 627503               CASS                  HIGHWAY TECH
# 627504               CASS                    MTL TECH 4
# 627505               CASS                     MTR VH OF
# 627506               CASS                    TRANS AIDE
# 627507               CASS                    DESIGN TEC
# 627508               CASS                   ENG TECH SR
# 627509               CASS                    TRANS AIDE
# 627510               CASS                  HIGHWAY TECH
# 627511               CASS                   EQUIP OP SR
# 627512               CASS                  HT ASSOCIATE
# 627513               CASS               Assistant Coach
# 627514               CASS   Clinical Dental House Staff
# 627515               CASS          Imaging Technologist
# 627516               CASS             WORKFORCE ADVISOR
# 627517               CASS                 FIELD AUDITOR
# 627518               CASS                       TEACHER
# 627519               CASS                       COOK II
# 627520               CASS          SCHOOL ASSISTANT SUB
# 627521               CASS                TEMP CHAPERONE
# 627522            O'BRIEN                 TEACHER OF VI
# 627523            O'BRIEN  Temp Prof Short Term Monthly
# 627524       BUFFALO CITY                    TRANS AIDE
#
#        Base Salary Payment Method  Base Salary Payment Amount  \
# 0                              HR                       31.62
# 1                              BW                     1226.40
# 2                      TERMINATED                         NaN
# 3                      TERMINATED                         NaN
# 4                      TERMINATED                         NaN
# 5                              BW                     2194.40
# 6                              BW                     3375.20
# 7                      TERMINATED                         NaN
# 8                              BW                     3349.60
# 9                              BW                     1237.60
# 10                             BW                     2908.80
# 11                             BW                     3193.60
# 12                             BW                     1598.40
# 13                     TERMINATED                         NaN
# 14                     TERMINATED                         NaN
# 15                             BW                     1180.80
# 16                             BW                     3087.20
# 17                             BW                     4792.00
# 18                     TERMINATED                         NaN
# 19                             BW                     1896.80
# 20                     TERMINATED                         NaN
# 21                     TERMINATED                         NaN
# 22                             BW                     2732.00
# 23                             BW                     2611.20
# 24                             BW                     3030.40
# 25                             BW                     1500.80
# 26                             BW                     3349.60
# 27                             BW                     3604.80
# 28                     TERMINATED                         NaN
# 29                             BW                      987.20
# ...                           ...                         ...
# 627495                         HR                       17.11
# 627496                         HR                       17.11
# 627497                         BW                     2373.60
# 627498                         BW                     2579.20
# 627499                         BW                     1826.40
# 627500                         BW                     2093.60
# 627501                         BW                     1875.20
# 627502                         BW                     2880.00
# 627503                         BW                     1531.20
# 627504                         BW                     2622.40
# 627505                         BW                     2475.20
# 627506                         HR                       17.11
# 627507                         BW                     2622.40
# 627508                         BW                     3013.60
# 627509                         HR                       17.11
# 627510                 TERMINATED                         NaN
# 627511                         BW                     2162.40
# 627512                         BW                     1966.40
# 627513                        NaN                   335000.00
# 627514                        NaN                        0.00
# 627515                        NaN                        0.00
# 627516                 TERMINATED                         NaN
# 627517                 TERMINATED                         NaN
# 627518                 TERMINATED                         NaN
# 627519                 TERMINATED                         NaN
# 627520                         HR                       14.09
# 627521                         HR                       16.83
# 627522                         YR                    77940.42
# 627523                        NaN                        0.00
# 627524                 TERMINATED                         NaN
#
#        Base Salary Date   ...    violent_crime_value  uninsured_value  \
# 0            2007-07-01   ...                 330.02            0.093
# 1            2007-07-01   ...                 330.02            0.093
# 2            2007-07-01   ...                 330.02            0.093
# 3            2007-07-01   ...                 330.02            0.093
# 4            2007-07-01   ...                 330.02            0.093
# 5            2007-07-01   ...                 330.02            0.093
# 6            2007-07-01   ...                 330.02            0.093
# 7            2007-07-01   ...                 330.02            0.093
# 8            2007-07-01   ...                 330.02            0.093
# 9            2007-07-01   ...                 330.02            0.093
# 10           2007-07-01   ...                 330.02            0.093
# 11           2007-07-01   ...                 330.02            0.093
# 12           2007-07-01   ...                 330.02            0.093
# 13           2007-07-01   ...                 330.02            0.093
# 14           2007-07-01   ...                 330.02            0.093
# 15           2007-07-01   ...                 330.02            0.093
# 16           2007-07-01   ...                 330.02            0.093
# 17           2007-07-01   ...                 330.02            0.093
# 18           2007-07-01   ...                 330.02            0.093
# 19           2007-07-01   ...                 330.02            0.093
# 20           2007-07-01   ...                 330.02            0.093
# 21           2007-07-01   ...                 330.02            0.093
# 22           2007-07-01   ...                 330.02            0.093
# 23           2007-07-01   ...                 330.02            0.093
# 24           2007-07-01   ...                 330.02            0.093
# 25           2007-07-01   ...                 330.02            0.093
# 26           2007-07-01   ...                 330.02            0.093
# 27           2007-07-01   ...                 330.02            0.093
# 28           2007-07-01   ...                 330.02            0.093
# 29           2007-07-01   ...                 330.02            0.093
# ...                 ...   ...                    ...              ...
# 627495       2017-07-01   ...                 145.74            0.101
# 627496       2017-07-01   ...                 145.74            0.101
# 627497       2017-07-01   ...                 145.74            0.101
# 627498       2017-07-01   ...                 145.74            0.101
# 627499       2017-07-01   ...                 145.74            0.101
# 627500       2017-07-01   ...                 145.74            0.101
# 627501       2017-07-01   ...                 145.74            0.101
# 627502       2017-07-01   ...                 145.74            0.101
# 627503       2017-07-01   ...                 145.74            0.101
# 627504       2017-07-01   ...                 145.74            0.101
# 627505       2017-07-01   ...                 145.74            0.101
# 627506       2017-07-01   ...                 145.74            0.101
# 627507       2017-07-01   ...                 145.74            0.101
# 627508       2017-07-01   ...                 145.74            0.101
# 627509       2017-07-01   ...                 145.74            0.101
# 627510       2017-07-01   ...                 145.74            0.101
# 627511       2017-07-01   ...                 145.74            0.101
# 627512       2017-07-01   ...                 145.74            0.101
# 627513       2017-07-01   ...                 145.74            0.101
# 627514       2017-07-01   ...                 145.74            0.101
# 627515       2017-07-01   ...                 145.74            0.101
# 627516       2017-07-01   ...                 145.74            0.101
# 627517       2017-07-01   ...                 145.74            0.101
# 627518       2017-07-01   ...                 145.74            0.101
# 627519       2017-07-01   ...                 145.74            0.101
# 627520       2017-07-01   ...                 145.74            0.101
# 627521       2017-07-01   ...                 145.74            0.101
# 627522       2017-07-01   ...                  81.14            0.105
# 627523       2017-07-01   ...                  81.14            0.105
# 627524       2017-07-01   ...                    NaN              NaN
#
#         density  percent_graduate_or_professional_degree  \
# 0       724.909                                      9.5
# 1       724.909                                      9.5
# 2       724.909                                      9.5
# 3       724.909                                      9.5
# 4       724.909                                      9.5
# 5       724.909                                      9.5
# 6       724.909                                      9.5
# 7       724.909                                      9.5
# 8       724.909                                      9.5
# 9       724.909                                      9.5
# 10      724.909                                      9.5
# 11      724.909                                      9.5
# 12      724.909                                      9.5
# 13      724.909                                      9.5
# 14      724.909                                      9.5
# 15      724.909                                      9.5
# 16      724.909                                      9.5
# 17      724.909                                      9.5
# 18      724.909                                      9.5
# 19      724.909                                      9.5
# 20      724.909                                      9.5
# 21      724.909                                      9.5
# 22      724.909                                      9.5
# 23      724.909                                      9.5
# 24      724.909                                      9.5
# 25      724.909                                      9.5
# 26      724.909                                      9.5
# 27      724.909                                      9.5
# 28      724.909                                      9.5
# 29      724.909                                      9.5
# ...         ...                                      ...
# 627495   23.806                                      5.0
# 627496   23.806                                      5.0
# 627497   23.806                                      5.0
# 627498   23.806                                      5.0
# 627499   23.806                                      5.0
# 627500   23.806                                      5.0
# 627501   23.806                                      5.0
# 627502   23.806                                      5.0
# 627503   23.806                                      5.0
# 627504   23.806                                      5.0
# 627505   23.806                                      5.0
# 627506   23.806                                      5.0
# 627507   23.806                                      5.0
# 627508   23.806                                      5.0
# 627509   23.806                                      5.0
# 627510   23.806                                      5.0
# 627511   23.806                                      5.0
# 627512   23.806                                      5.0
# 627513   23.806                                      5.0
# 627514   23.806                                      5.0
# 627515   23.806                                      5.0
# 627516   23.806                                      5.0
# 627517   23.806                                      5.0
# 627518   23.806                                      5.0
# 627519   23.806                                      5.0
# 627520   23.806                                      5.0
# 627521   23.806                                      5.0
# 627522   24.527                                      4.8
# 627523   24.527                                      4.8
# 627524  190.214                                      1.7
#
#         percent_some_college  percent_less_than_9th_grade  \
# 0                       21.3                          3.3
# 1                       21.3                          3.3
# 2                       21.3                          3.3
# 3                       21.3                          3.3
# 4                       21.3                          3.3
# 5                       21.3                          3.3
# 6                       21.3                          3.3
# 7                       21.3                          3.3
# 8                       21.3                          3.3
# 9                       21.3                          3.3
# 10                      21.3                          3.3
# 11                      21.3                          3.3
# 12                      21.3                          3.3
# 13                      21.3                          3.3
# 14                      21.3                          3.3
# 15                      21.3                          3.3
# 16                      21.3                          3.3
# 17                      21.3                          3.3
# 18                      21.3                          3.3
# 19                      21.3                          3.3
# 20                      21.3                          3.3
# 21                      21.3                          3.3
# 22                      21.3                          3.3
# 23                      21.3                          3.3
# 24                      21.3                          3.3
# 25                      21.3                          3.3
# 26                      21.3                          3.3
# 27                      21.3                          3.3
# 28                      21.3                          3.3
# 29                      21.3                          3.3
# ...                      ...                          ...
# 627495                  20.7                          2.8
# 627496                  20.7                          2.8
# 627497                  20.7                          2.8
# 627498                  20.7                          2.8
# 627499                  20.7                          2.8
# 627500                  20.7                          2.8
# 627501                  20.7                          2.8
# 627502                  20.7                          2.8
# 627503                  20.7                          2.8
# 627504                  20.7                          2.8
# 627505                  20.7                          2.8
# 627506                  20.7                          2.8
# 627507                  20.7                          2.8
# 627508                  20.7                          2.8
# 627509                  20.7                          2.8
# 627510                  20.7                          2.8
# 627511                  20.7                          2.8
# 627512                  20.7                          2.8
# 627513                  20.7                          2.8
# 627514                  20.7                          2.8
# 627515                  20.7                          2.8
# 627516                  20.7                          2.8
# 627517                  20.7                          2.8
# 627518                  20.7                          2.8
# 627519                  20.7                          2.8
# 627520                  20.7                          2.8
# 627521                  20.7                          2.8
# 627522                  20.9                          3.3
# 627523                  20.9                          3.3
# 627524                  23.6                          4.9
#
#         percent_associates_degree  percent_bachelors_degree_or_higher  \
# 0                             9.4                                32.8
# 1                             9.4                                32.8
# 2                             9.4                                32.8
# 3                             9.4                                32.8
# 4                             9.4                                32.8
# 5                             9.4                                32.8
# 6                             9.4                                32.8
# 7                             9.4                                32.8
# 8                             9.4                                32.8
# 9                             9.4                                32.8
# 10                            9.4                                32.8
# 11                            9.4                                32.8
# %% [markdown]
# ## End of initial data munging

# %% [markdown]
# ## Hypothesis Testing

# %%
# Filter data so that every row has a value for each given attribute
def filterDataOnAttrs(attrs):
    usefulData = fullData
    for a in attrs:
        usefulData = usefulData[usefulData[a].notnull()]
    return usefulData

# Remove outliers for the given attribute using the Tukey method
def removeOutliersTukey(usefulData, attr):
    thirdQuartile = usefulData.quantile(.75)[attr]
    firstQuartile = usefulData.quantile(.25)[attr]
    IQR = thirdQuartile - firstQuartile
    return usefulData[usefulData[attr].between(firstQuartile - IQR * 1.5, thirdQuartile + IQR * 1.5)]

# Prepare the data for use
def prepData(attrs, predictor, minYear, maxYear):
    # Only consider data that exists for the attributes we want
    usefulData = filterDataOnAttrs(attrs)
    # Restrict to range of years
    usefulData = usefulData[usefulData['Fiscal Year'].dt.year.between(minYear, maxYear)]
    # Remove outliers
    usefulData = removeOutliersTukey(usefulData, predictor)
    return usefulData

# %% [markdown]
# ## Linear Regression

# %%
# Values to predict on
regressors = [
  'adult_obesity_value',
  'children_in_poverty_value',
  'income_inequality_value',
  'median_household_income_value',
  'unemployment_value',
  'violent_crime_value',
  'uninsured_value',
  'density',
  'count',
  'some_college_value',
  'percent_graduate_or_professional_degree',
  'percent_some_college',
  'percent_less_than_9th_grade',
  'percent_associates_degree',
  'percent_bachelors_degree_or_higher',
  'percent_high_school_graduate',
]

# Values we want to predict
predictors = ['Hourly Wage Estimate','median_household_income_value']

# We only want to work on one year at a time to ignore the effects of inflation
targetYear = 2016

# Average per area used instead of raw data to prevent high-population spots from weighing too much
useAvg = True

for predictor in predictors:
    print("Predicting " + predictor)
    
    # Filter on attrs, restrict to year, and remove outliers
    usefulData = prepData(regressors + [predictor], predictor, targetYear, targetYear)
    
    # We want to have one entry for each area, where the hourly wage is the average for that area
    if useAvg:
        usefulData = usefulData.groupby(['Place of Residence']).mean()

    # Run MLR
    LR = linear_model.LinearRegression()
    train_x = usefulData[regressors]
    train_y = usefulData[[predictor]]
    LR.fit(train_x, train_y)
    pred = LR.predict(train_x)
    MLR_coef = LR.coef_[0]

    # Run SLR and compare each result to MLR counterpart, and print SLR line graph
    train_y = usefulData[[predictor]]
    for ri, r in enumerate(regressors):
        # Get datapoints for this variable and normalize them
        train_x = usefulData[[r]]
        train_x = (train_x - train_x.min()) / (train_x.max() - train_x.min())

        # Run SLR
        LR = linear_model.LinearRegression()
        LR.fit(train_x, train_y)
        pred = LR.predict(train_x)
        coef = LR.coef_[0][0]
        
        # Get error
        errors = np.array(sorted([(p-y) for y, p in zip(np.array(train_y), pred)]))
        
        # Get error CDF
        curVal = 0
        X_errs = np.arange(min(errors)-1, max(errors)+1, .1)
        CDF = []
        for i in X_errs:
            while curVal < len(errors) and errors[curVal] <= i:
                curVal += 1
            v = float(curVal) / len(errors)
            CDF.append(v)
        plt.plot(X_errs, CDF, color="red")
        plt.show()
        
        # Get error PDF
        curVal = 0
        X_errs = np.arange(min(errors)-1, max(errors)+1, .5)
        PDF = []
        for i in X_errs:
            PDF.append(sum(1 for e in errors if e > i and e <= i + .5))
        plt.plot(X_errs, PDF, color="red")
        plt.show()
        
        # Check error distribution
        ks = stats.kstest(errors, 'norm')
        se = math.sqrt(sum((p-y)**2 for y, p in zip(np.array(train_y), pred)) / len(pred))
        t_val = abs(coef / se)

        # Report results and plot graph
        print(r)
        print("SLR: {0:.2f}, se: {1:.2f}, T: {2:.2f}, MLR: {3:.2f}".format(coef, se, t_val, MLR_coef[ri]))
        print("Mean Error: {0:.2f}, Error KS-test: {1}".format(np.mean(errors), ks))
        plt.scatter(train_x, train_y, color='black', s=1)
        plt.plot(train_x, pred, color='blue', linewidth=3)
        plt.show()
# Out:
# Predicting Hourly Wage Estimate
# 89
# adult_obesity_value
# SLR: -0.36, se: 1.58, T: 0.23, MLR: 5.27
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.9999860214123123, pvalue=0.0)
# 89
# children_in_poverty_value
# SLR: -1.07, se: 1.57, T: 0.68, MLR: -5.33
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99998029327596782, pvalue=0.0)
# 89
# income_inequality_value
# SLR: 1.74, se: 1.54, T: 1.13, MLR: 1.23
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99997262769392636, pvalue=0.0)
# 89
# median_household_income_value
# SLR: 1.71, se: 1.56, T: 1.10, MLR: 0.00
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99995573724289299, pvalue=0.0)
# 89
# unemployment_value
# SLR: 0.62, se: 1.58, T: 0.40, MLR: 23.41
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99998073915451824, pvalue=0.0)
# 89
# violent_crime_value
# SLR: 0.22, se: 1.58, T: 0.14, MLR: -0.00
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99998518765891931, pvalue=0.0)
# 89
# uninsured_value
# SLR: -2.79, se: 1.48, T: 1.88, MLR: -11.15
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.9999272206090567, pvalue=0.0)
# 89
# density
# SLR: 4.33, se: 1.48, T: 2.92, MLR: 0.01
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99999174404353042, pvalue=0.0)
# 89
# count
# SLR: 4.18, se: 1.49, T: 2.81, MLR: -0.00
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99999174970471372, pvalue=0.0)
# 89
# some_college_value
# SLR: 2.31, se: 1.52, T: 1.52, MLR: 3.23
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99998860158190495, pvalue=0.0)
# 89
# percent_graduate_or_professional_degree
# SLR: 2.36, se: 1.54, T: 1.53, MLR: -0.10
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99999071494505054, pvalue=0.0)
# 89
# percent_some_college
# SLR: -0.60, se: 1.58, T: 0.38, MLR: 0.04
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99998019357386325, pvalue=0.0)
# 89
# percent_less_than_9th_grade
# SLR: -2.71, se: 1.51, T: 1.80, MLR: -0.02
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99997593425722109, pvalue=0.0)
# 89
# percent_associates_degree
# SLR: -1.19, se: 1.56, T: 0.77, MLR: -0.19
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99998102520064736, pvalue=0.0)
# 89
# percent_bachelors_degree_or_higher
# SLR: 2.59, se: 1.51, T: 1.72, MLR: 0.08
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99997411215309229, pvalue=0.0)
# 89
# percent_high_school_graduate
# SLR: -0.99, se: 1.57, T: 0.63, MLR: 0.12
# Mean Error: 0.00, Error KS-test: KstestResult(statistic=0.99999016645823591, pvalue=0.0)
# Predicting median_household_income_value
# 57
# adult_obesity_value
# SLR: -1010.84, se: 3338.54, T: 0.30, MLR: -0.00
# Mean Error: -0.00, Error KS-test: KstestResult(statistic=1.0, pvalue=0.0)
# 57
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-bc42dde5bcc8> in <module>()
#      80         PDF = []
#      81         for i in X_errs:
# ---> 82             PDF.append(sum(1 for e in errors if e > i and e <= i + .5))
#      83         plt.plot(X_errs, PDF, color="red")
#      84         plt.show()
#
# <ipython-input-31-bc42dde5bcc8> in <genexpr>((e,))
#      80         PDF = []
#      81         for i in X_errs:
# ---> 82             PDF.append(sum(1 for e in errors if e > i and e <= i + .5))
#      83         plt.plot(X_errs, PDF, color="red")
#      84         plt.show()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Wald's and K-S

# %%
def WaldsTest(df1, df2):
    w = (df1.mean() - df2.mean())/math.sqrt(df1.var()/len(df1) + df2.var()/len(df2))
    p_value = 2 * (1 - stats.norm.cdf(abs(w)))
    return w, p_value

def TTest(df):
    t = df.mean() / math.sqrt(df.var()/len(df))
    return t

# %%
# Prepare data for experiment
predictor = 'Hourly Wage Estimate'
targetYear = 2016
usefulData = prepData([predictor], predictor, targetYear, targetYear)

attributes = [
  'adult_obesity_value',
  'children_in_poverty_value',
  'income_inequality_value',
  'median_household_income_value',
  'unemployment_value',
  'violent_crime_value',
  'uninsured_value',
  'density',
  'count',
  'some_college_value',
  'percent_graduate_or_professional_degree',
  'percent_some_college',
  'percent_less_than_9th_grade',
  'percent_associates_degree',
  'percent_bachelors_degree_or_higher',
  'percent_high_school_graduate', 
]

cutOnPop = False
quartiles = [.25,.75]

for a in attributes:
    usefulData = usefulData[usefulData[a].notnull()]
    if cutOnPop:
        firstQuartile = usefulData.quantile(quartiles[0])[a]
        thirdQuartile = usefulData.quantile(quartiles[1])[a]
        pop1 = usefulData[usefulData[a] < firstQuartile]
        pop2 = usefulData[usefulData[a] >= thirdQuartile]
    else:
        usefulResData = residenceData[residenceData['Fiscal Year'].dt.year == targetYear]
        usefulResData = pd.merge(usefulResData, usefulData, on='Place of Residence', suffixes=('_x',''))
        
        firstQuartile = usefulResData.quantile(quartiles[0])[a]
        thirdQuartile = usefulResData.quantile(quartiles[1])[a]
        res1 = usefulResData[usefulResData[a] < firstQuartile]['Place of Residence']
        res2 = usefulResData[usefulResData[a] >= thirdQuartile]['Place of Residence']
        pop1 = usefulData[usefulData['Place of Residence'].isin(res1)]
        pop2 = usefulData[usefulData['Place of Residence'].isin(res2)]
        
    if len(pop1) == 0 or len(pop2) == 0:
        print firstQuartile
        print thirdQuartile
        print pop1
        print pop2
        continue
    
    w, p_value = WaldsTest(pop1[predictor], pop2[predictor])
    k_stat = stats.ks_2samp(pop1[predictor], pop2[predictor])
    print("Low vs High {0}: w={1:.3f}, k-s={2}".format(a, w, k_stat))
    print("Avg Lower Quartile={0:.3f}, Avg Higher Quartile={1:.3f}".format(pop1[predictor].mean(), pop2[predictor].mean()))
    
    plt.plot(pop1[predictor].value_counts().sort_index().apply((lambda x: x/float(len(pop1)))).cumsum(), color="red")
    plt.plot(pop2[predictor].value_counts().sort_index().apply((lambda x: x/float(len(pop2)))).cumsum(), color="green")
    
    plt.show()
# Out:
# Low vs High adult_obesity_value: w=4.542, k-s=Ks_2sampResult(statistic=0.07084364882879457, pvalue=1.048305358147706e-08)
# Avg Lower Quartile=27.253, Avg Higher Quartile=26.317
# Low vs High children_in_poverty_value: w=7.055, k-s=Ks_2sampResult(statistic=0.081977307599127802, pvalue=4.4859723829096142e-15)
# Avg Lower Quartile=27.577, Avg Higher Quartile=26.340
# Low vs High income_inequality_value: w=-6.169, k-s=Ks_2sampResult(statistic=0.10345922608029118, pvalue=9.5125992927361917e-24)
# Avg Lower Quartile=26.213, Avg Higher Quartile=27.280
# Low vs High median_household_income_value: w=-20.737, k-s=Ks_2sampResult(statistic=0.19291982018589049, pvalue=4.4002312811257713e-93)
# Avg Lower Quartile=26.887, Avg Higher Quartile=30.276
# Low vs High unemployment_value: w=-0.636, k-s=Ks_2sampResult(statistic=0.083547015816896442, pvalue=1.1429120110419156e-15)
# Avg Lower Quartile=26.475, Avg Higher Quartile=26.585
# Low vs High violent_crime_value: w=-11.916, k-s=Ks_2sampResult(statistic=0.10365323032630003, pvalue=1.7999186058312611e-30)
# Avg Lower Quartile=27.129, Avg Higher Quartile=28.968
# Low vs High uninsured_value: w=5.832, k-s=Ks_2sampResult(statistic=0.043527282079589225, pvalue=0.00019692571972381858)
# Avg Lower Quartile=27.021, Avg Higher Quartile=26.021
# Low vs High density: w=-25.975, k-s=Ks_2sampResult(statistic=0.24297310357443297, pvalue=7.9062874482119116e-133)
# Avg Lower Quartile=26.190, Avg Higher Quartile=30.776
# Low vs High count: w=-25.483, k-s=Ks_2sampResult(statistic=0.23800665328371534, pvalue=7.2752757195485062e-128)
# Avg Lower Quartile=26.281, Avg Higher Quartile=30.776
# Low vs High some_college_value: w=-19.710, k-s=Ks_2sampResult(statistic=0.16341580879677042, pvalue=4.5298573831815898e-75)
# Avg Lower Quartile=26.339, Avg Higher Quartile=29.371
# Low vs High percent_graduate_or_professional_degree: w=-16.821, k-s=Ks_2sampResult(statistic=0.16770162077719186, pvalue=3.3914080994063264e-66)
# Avg Lower Quartile=26.836, Avg Higher Quartile=29.656
# Low vs High percent_some_college: w=3.129, k-s=Ks_2sampResult(statistic=0.054535802594953831, pvalue=5.8276768117550811e-07)
# Avg Lower Quartile=27.089, Avg Higher Quartile=26.544
# Low vs High percent_less_than_9th_grade: w=-8.061, k-s=Ks_2sampResult(statistic=0.086704062066340515, pvalue=5.9811627384467268e-20)
# Avg Lower Quartile=27.325, Avg Higher Quartile=28.694
# Low vs High percent_associates_degree: w=-1.238, k-s=Ks_2sampResult(statistic=0.09570113395644414, pvalue=6.3251565300596819e-20)
# Avg Lower Quartile=26.332, Avg Higher Quartile=26.548
# Low vs High percent_bachelors_degree_or_higher: w=-21.520, k-s=Ks_2sampResult(statistic=0.18810453154846174, pvalue=3.5650238432085845e-93)
# Avg Lower Quartile=26.302, Avg Higher Quartile=29.778
# Low vs High percent_high_school_graduate: w=3.129, k-s=Ks_2sampResult(statistic=0.090799689953714346, pvalue=3.439011639087932e-12)
# Avg Lower Quartile=27.479, Avg Higher Quartile=26.750

# %% [markdown]
# ## Weird Wald's/K-S Thing we probably won't use

# %%
# Prepare data for experiment
predictor = 'Hourly Wage Estimate'
targetYear = 2016
usefulData = prepData([predictor], predictor, targetYear, targetYear)
allResidences = list(fullData["Place of Residence"].unique())

# Will map pair of residences to w and k-s statistics
cityPairCompResults = dict()

# Compare all pairs of residences
for r1i in range(0, len(allResidences)):
    for r2i in range(r1i + 1, len(allResidences)):
        # Get residence names
        r1n = allResidences[r1i]
        r2n = allResidences[r2i]
        
        # Get salary data for all people from each residence
        r1 = usefulData[usefulData['Place of Residence'] == r1n][predictor]
        r2 = usefulData[usefulData['Place of Residence'] == r2n][predictor]
        
        # Run Wald's test and K-S test on populations
        if len(r1) == 0 or len(r2) == 0:
            continue
        w, p_value = WaldsTest(r1, r2)
        k_stat = stats.ks_2samp(r1, r2).statistic
        cityPairCompResults[(r1n, r2n)] = (w, k_stat)

# %%
# Plot differences in W and K-S to differences in attributes
yearlyData = residenceData[residenceData['Fiscal Year'].dt.year == targetYear]
attributes = [
  'adult_obesity_value',
  'children_in_poverty_value',
  'income_inequality_value',
  'median_household_income_value',
  'unemployment_value',
  'violent_crime_value',
  'uninsured_value',
  'density',
  'count',
  #'some_college_value',
  #'percent_graduate_or_professional_degree',
  #'percent_some_college',
  #'percent_less_than_9th_grade',
  #'percent_associates_degree',
  #'percent_bachelors_degree_or_higher',
  #'percent_high_school_graduate', 
]
LR = linear_model.LinearRegression()
for a in attributes:
    print("Differences in " + a)
    
    # Get difference between attribute values for residences and their salary statistics
    x = []
    y = []
    for (r1, r2), (w, k) in cityPairCompResults.items():
        # Get attribute for areas and their difference
        r1a = yearlyData[yearlyData['Place of Residence'] == r1][a].iloc[0]
        r2a = yearlyData[yearlyData['Place of Residence'] == r2][a].iloc[0]
        if np.isnan(r1a) or np.isnan(r2a):
            continue
        dif = abs(r1a - r2a)
        
        # Add difference for x value and statistic for y value
        x.append(dif)
        y.append(abs(k))
    
    # Normalize x values
    x = np.array(x).reshape(-1, 1)
    x = (x - x.min()) / (x.max() - x.min())
    
    # Run Simple LR
    LR.fit(x, y)
    pred = LR.predict(x)
    
    # Plot results
    print(LR.coef_[0])
    plt.scatter(x, y, color='black', s=.1)
    plt.plot(x, pred, linewidth=1)
    plt.show()
# Out:
# Differences in adult_obesity_value
# -0.0065240784784
# Differences in children_in_poverty_value
# -0.00410278830149
# Differences in income_inequality_value
# -0.0027275593629
# Differences in median_household_income_value
# -0.0088083509112
# Differences in unemployment_value
# -0.00397619963557
# Differences in violent_crime_value
# 0.0164534789811
# Differences in uninsured_value
# -0.00406585216047
# Differences in density
# 0.0730751268282
# Differences in count
# 0.749505771753

# %% [markdown]
# ## Long-term residents vs Newcomers

# %% [markdown]
# H: The 5-year future salary of someone who just moved to a city is the same as that of someone who has lived there for n+ years

# %%
predictor = 'Hourly Wage Estimate'
usefulData = prepData([predictor], predictor, 2006, 2018)
startYear = 2007
#residences = ['POLK', 'JOHNSON', 'STORY', 'BLACK HAWK', 'LINN', 'BOONE', 'WASHINGTON']
residences = usefulData['Place of Residence'].value_counts()[:10]
#print residences
residences = residences.index.tolist()

showGraphs = False

# n is min number of years to be a 'long-term' resident
for n in range(2,5):
    # targetYear is how many years after moving we want to compare salaries
    for targetYear in range(0, 6):
        salary_difs = []
        for residence in residences:
            # Get people who lived here in start year
            inrespop = usefulData[(usefulData['Place of Residence'] == residence) & (usefulData['Fiscal Year'].dt.year == startYear)]

            # Do calculations moving forward one year at a time
            for y in range(startYear+1, 2018):
                # Get people who live in the residence now
                inresnow = usefulData[(usefulData['Place of Residence'] == residence) & (usefulData['Fiscal Year'].dt.year == y)]

                # People who live here now and have lived here in the past
                inrespop = pd.merge(inrespop, inresnow, on='Name', suffixes=('_x',''))
                inrespop = inrespop[inrespop['Fiscal Year'].dt.year == y]
                inrespop_mean = inrespop[predictor].mean()

                # Get people who did not live here last year but live here now
                notinresbefore = usefulData[(usefulData['Place of Residence'] != residence) & (usefulData['Fiscal Year'].dt.year == y-1)]
                newcomers = pd.merge(notinresbefore, inresnow, on='Name', suffixes=('_x',''))
                newcomers = newcomers[newcomers['Fiscal Year'].dt.year == y]
                newcomers_mean = newcomers[predictor].mean()

                # Now show how these populations perform going forward
                inpop_sub = []
                newcome_sub = []
                pop1 = inrespop
                pop2 = newcomers
                for m in range(y, 2018):
                    inresnow = inresnow = usefulData[(usefulData['Place of Residence'] == residence) & (usefulData['Fiscal Year'].dt.year == m)]
                    pop1 = pd.merge(pop1, inresnow, on='Name', suffixes=('_x',''))
                    pop1 = pop1[pop1['Fiscal Year'].dt.year == m]
                    pop1_mean = pop1[predictor].mean()
                    pop2 = pd.merge(pop2, inresnow, on='Name', suffixes=('_x',''))
                    pop2 = pop2[pop2['Fiscal Year'].dt.year == m]
                    pop2_mean = pop2[predictor].mean()
                    inpop_sub.append(pop1_mean)
                    newcome_sub.append(pop2_mean)

                    if m - y == targetYear and y - startYear >= n and not np.isnan(pop1_mean) and not np.isnan(pop2_mean):
                        salary_difs.append(pop1_mean - pop2_mean)

                if showGraphs:
                    print("{0}: {1}-year residents vs newcomers from {2} onward".format(residence, y-startYear, y))
                    plt.plot(range(y,2018), inpop_sub, color='blue')
                    plt.plot(range(y,2018), newcome_sub, color='green')
                    plt.show()

        salary_difs = np.array(salary_difs)
        t = TTest(salary_difs)
        print("\nLong-Term residence req: {0}, Future comparison year: {1}".format(n, targetYear))
        print("Avg difference in mean salary: {0}".format(salary_difs.mean()))
        print("T-stat: {0}, n: {1}".format(t, len(salary_difs)))
# Out:
# Long-Term residence req: 2, Future comparison year: 0
# Avg difference in mean salary: 3.00673385094
# T-stat: 10.6696419637, n: 90
#
# Long-Term residence req: 2, Future comparison year: 1
# Avg difference in mean salary: 1.96775772594
# T-stat: 6.22256503282, n: 80
#
# Long-Term residence req: 2, Future comparison year: 2
# Avg difference in mean salary: 1.29254205766
# T-stat: 3.71358151509, n: 70
#
# Long-Term residence req: 2, Future comparison year: 3
# Avg difference in mean salary: 0.453394268658
# T-stat: 1.40042546602, n: 60
#
# Long-Term residence req: 2, Future comparison year: 4
# Avg difference in mean salary: -0.488653865408
# T-stat: -1.18046884537, n: 50
#
# Long-Term residence req: 2, Future comparison year: 5
# Avg difference in mean salary: -1.19762450481
# T-stat: -2.95925743393, n: 40
#
# Long-Term residence req: 3, Future comparison year: 0
# Avg difference in mean salary: 3.0519012712
# T-stat: 9.87566640749, n: 80
#
# Long-Term residence req: 3, Future comparison year: 1
# Avg difference in mean salary: 2.01921557466
# T-stat: 5.81575962634, n: 70
#
# Long-Term residence req: 3, Future comparison year: 2
# Avg difference in mean salary: 1.36942557495
# T-stat: 3.60042182171, n: 60
#
# Long-Term residence req: 3, Future comparison year: 3
# Avg difference in mean salary: 0.518945016388
# T-stat: 1.47003820201, n: 50
#
# Long-Term residence req: 3, Future comparison year: 4
# Avg difference in mean salary: -0.553367813767
# T-stat: -1.20716519227, n: 40
#
# Long-Term residence req: 3, Future comparison year: 5
# Avg difference in mean salary: -1.15868143181
# T-stat: -2.64158771702, n: 30
#
# Long-Term residence req: 4, Future comparison year: 0
# Avg difference in mean salary: 3.14335945011
# T-stat: 9.44278989403, n: 70
#
# Long-Term residence req: 4, Future comparison year: 1
# Avg difference in mean salary: 2.12188319453
# T-stat: 5.58751794458, n: 60
#
# Long-Term residence req: 4, Future comparison year: 2
# Avg difference in mean salary: 1.47674480357
# T-stat: 3.46248346419, n: 50
#
# Long-Term residence req: 4, Future comparison year: 3
# Avg difference in mean salary: 0.549624098421
# T-stat: 1.38749856597, n: 40
#
# Long-Term residence req: 4, Future comparison year: 4
# Avg difference in mean salary: -0.295781577583
# T-stat: -0.567845583465, n: 30
#
# Long-Term residence req: 4, Future comparison year: 5
# Avg difference in mean salary: -0.957713636444
# T-stat: -1.99964897551, n: 20

# %%
# TODO: for each residence...
#           for y in range(2007,2017)...
#               for m in range(0,max)...
#                   get average salary for people who have lived in city since y for m years
#                   calculate TSA predictors for y to 2017
#                   make future predictions
#           compare AR B vectors for different m's and y's
